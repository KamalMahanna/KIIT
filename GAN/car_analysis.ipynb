# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cars.csv')

# %%
df
# Out:
#     Car_ID     Brand          Model  Year  Kilometers_Driven Fuel_Type  \
# 0        1    Toyota        Corolla  2018              50000    Petrol
# 1        2     Honda          Civic  2019              40000    Petrol
# 2        3      Ford        Mustang  2017              20000    Petrol
# 3        4    Maruti          Swift  2020              30000    Diesel
# 4        5   Hyundai         Sonata  2016              60000    Diesel
# ..     ...       ...            ...   ...                ...       ...
# 95      96  Mercedes        C-Class  2019              22000    Diesel
# 96      97    Toyota  Innova Crysta  2017              38000    Diesel
# 97      98      Ford       EcoSport  2018              26000    Petrol
# 98      99   Hyundai          Verna  2019              24000    Petrol
# 99     100      Tata         Altroz  2020              18000    Petrol
#
#    Transmission Owner_Type  Mileage  Engine  Power  Seats    Price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Car_ID             100 non-null    int64
#  1   Brand              100 non-null    object
#  2   Model              100 non-null    object
#  3   Year               100 non-null    int64
#  4   Kilometers_Driven  100 non-null    int64
#  5   Fuel_Type          100 non-null    object
#  6   Transmission       100 non-null    object
#  7   Owner_Type         100 non-null    object
#  8   Mileage            100 non-null    int64
#  9   Engine             100 non-null    int64
#  10  Power              100 non-null    int64
#  11  Seats              100 non-null    int64
#  12  Price              100 non-null    int64
# dtypes: int64(8), object(5)
# memory usage: 10.3+ KB

# %%
df.describe()
# Out:
#            Car_ID        Year  Kilometers_Driven     Mileage       Engine  \
# count  100.000000   100.00000         100.000000  100.000000   100.000000
# mean    50.500000  2018.39000       28150.000000   17.210000  1855.230000
# std     29.011492     1.17116        9121.375716    3.309902   631.311475
# min      1.000000  2016.00000       10000.000000   10.000000   999.000000
# 25%     25.750000  2017.75000       22000.000000   15.000000  1462.000000
# 50%     50.500000  2018.00000       27000.000000   17.000000  1774.000000
# 75%     75.250000  2019.00000       32000.000000   19.000000  2143.000000
# max    100.000000  2021.00000       60000.000000   25.000000  4951.000000
#
#             Power       Seats         Price
# count  100.000000  100.000000  1.000000e+02
# mean   158.130000    5.230000  1.574000e+06
# std     76.968137    0.750151  1.000265e+06
# min     68.000000    4.000000  4.500000e+05
# 25%    103.000000    5.000000  7.000000e+05
# ...

# %%
df['Price'].mean()
# Out:
# np.float64(1574000.0)

# %%
df['Price'].median()
# Out:
# np.float64(1300000.0)

# %%
df['Price'].min()
# Out:
# np.int64(450000)

# %%
df['Price'].max()
# Out:
# np.int64(4000000)

# %%
df['Price'].skew()
# Out:
# np.float64(0.6142859340595381)

# %%
df['Price'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Price'].plot.box()
# Out:
# <Axes: >

# %%
df['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    52
# Diesel    48
# Name: count, dtype: int64

# %%
pd.set_option('display.float_format', lambda x: '%.9f' % x)

# %%
df[['Fuel_Type','Price']].groupby('Fuel_Type').mean()
# Out:
#                       Price
# Fuel_Type
# Diesel    1761458.333333333
# Petrol    1400961.538461538

# %%
df.drop('Car_ID',axis=1,inplace=True)

# %%
for i in ['Year','Kilometers_Driven','Mileage','Engine','Power','Seats','Price']:
    plt.boxplot(df[i])
    plt.title(i)
    plt.show()

# %%
df
# Out:
#        Brand          Model  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0     Toyota        Corolla  2018              50000    Petrol       Manual
# 1      Honda          Civic  2019              40000    Petrol    Automatic
# 2       Ford        Mustang  2017              20000    Petrol    Automatic
# 3     Maruti          Swift  2020              30000    Diesel       Manual
# 4    Hyundai         Sonata  2016              60000    Diesel    Automatic
# ..       ...            ...   ...                ...       ...          ...
# 95  Mercedes        C-Class  2019              22000    Diesel    Automatic
# 96    Toyota  Innova Crysta  2017              38000    Diesel       Manual
# 97      Ford       EcoSport  2018              26000    Petrol       Manual
# 98   Hyundai          Verna  2019              24000    Petrol    Automatic
# 99      Tata         Altroz  2020              18000    Petrol       Manual
#
#    Owner_Type  Mileage  Engine  Power  Seats    Price
# ...

# %%
for i in ['Year','Kilometers_Driven','Mileage','Engine','Power']:
    df.plot.scatter(i,'Price')
    plt.title(i+" vs Price")
    plt.xlabel(i)
    plt.ylabel('Price')
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
leBrand = LabelEncoder()

# %%
df['Brand'].unique()
# Out:
# array(['Toyota', 'Honda', 'Ford', 'Maruti', 'Hyundai', 'Tata', 'Mahindra',
#        'Volkswagen', 'Audi', 'BMW', 'Mercedes'], dtype=object)

# %%
df['Brand'] = leBrand.fit_transform(df['Brand'])

# %%
leModel = LabelEncoder()
df['Model'] = leModel.fit_transform(df['Model'])
leFuel_Type = LabelEncoder()
df['Fuel_Type'] = leFuel_Type.fit_transform(df['Fuel_Type'])
leTransmission = LabelEncoder()
df['Transmission'] = leTransmission.fit_transform(df['Transmission'])
leOwner_Type = LabelEncoder()
df['Owner_Type'] = leOwner_Type.fit_transform(df['Owner_Type'])

# %%
df
# Out:
#     Brand  Model  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0       9     15  2018              50000          1             1
# 1       3     14  2019              40000          1             0
# 2       2     30  2017              20000          1             0
# 3       6     42  2020              30000          0             1
# 4       4     41  2016              60000          0             0
# ..    ...    ...   ...                ...        ...           ...
# 95      7     11  2019              22000          0             0
# 96      9     29  2017              38000          0             1
# 97      2     18  2018              26000          1             1
# 98      4     50  2019              24000          1             0
# 99      8      7  2020              18000          1             1
#
#     Owner_Type  Mileage  Engine  Power  Seats    Price
# 0            0       15    1498    108      5   800000
# ...

# %%
cont_cols = ['Year','Kilometers_Driven','Mileage','Engine','Power','Price']

# %%
Q1 = df[cont_cols].quantile(0.25)
Q3 = df[cont_cols].quantile(0.75)
IQR = Q3-Q1

# %%
df[((df[cont_cols]<(Q1-1.5*IQR)) | (df[cont_cols]>(Q3+1.5*IQR))).any(axis=1)]
# Out:
#     Brand  Model  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0       9     15  2018              50000          1             1
# 2       2     30  2017              20000          1             0
# 4       4     41  2016              60000          0             0
# 20      9     28  2018              50000          0             1
# 24      5     44  2021              10000          0             1
# 38      7     26  2018              26000          1             0
# 47      1     55  2018              28000          1             0
# 50      2     30  2019              22000          1             0
# 62      5     44  2021              10000          0             1
# 76      7     26  2018              26000          1             0
# 85      1     55  2018              28000          1             0
# 88      2     30  2019              22000          1             0
#
#     Owner_Type  Mileage  Engine  Power  Seats    Price
# ...

# %%
df_clean = df[~((df[cont_cols]<(Q1-1.5*IQR)) | (df[cont_cols]>(Q3+1.5*IQR))).any(axis=1)]
df_clean
# Out:
#     Brand  Model  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 1       3     14  2019              40000          1             0
# 3       6     42  2020              30000          0             1
# 5       8     31  2019              35000          1             1
# 6       5     40  2018              45000          0             0
# 7      10     33  2020              25000          1             0
# ..    ...    ...   ...                ...        ...           ...
# 95      7     11  2019              22000          0             0
# 96      9     29  2017              38000          0             1
# 97      2     18  2018              26000          1             1
# 98      4     50  2019              24000          1             0
# 99      8      7  2020              18000          1             1
#
#     Owner_Type  Mileage  Engine  Power  Seats    Price
# 1            1       17    1597    140      5  1000000
# ...

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df_clean.corr(),annot=True,fmt=".2f")
# Out:
# <Axes: >
